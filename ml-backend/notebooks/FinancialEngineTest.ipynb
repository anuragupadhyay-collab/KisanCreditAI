# %%
import sys
import os

sys.path.append("../src")

from revenue_engine import *

# %%
land_area = 5
yield_per_acre = 2.5
predicted_price = 24000
cultivation_cost = 180000
loan_amount = 200000
interest_rate = 9
tenure = 12

production = compute_production(land_area, yield_per_acre)
revenue = compute_revenue(production, predicted_price)
profit = compute_profit(revenue, cultivation_cost)
emi = compute_emi(loan_amount, interest_rate, tenure)
margin = compute_profit_margin(profit, revenue)
ratio = compute_debt_to_profit_ratio(loan_amount, profit)

print("Production:", production)
print("Revenue:", revenue)
print("Profit:", profit)
print("EMI:", emi)
print("Profit Margin:", margin)
print("Debt Ratio:", ratio)
# Out:
# Production: 12.5
# Revenue: 300000.0
# Profit: 120000.0
# EMI: 17490.3
# Profit Margin: 40.0
# Debt Ratio: 1.67
