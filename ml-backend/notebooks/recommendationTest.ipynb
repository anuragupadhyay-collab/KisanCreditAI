# %%
import sys

sys.path.append("../src")

from recommendation_engine import *

# %%
result = generate_recommendation(
    risk="SAFE",
    profit=180000,
    revenue=450000,
    emi=15000,
    loan_amount=100000,
    profit_margin=40,
    debt_ratio=0.55
)

result
# Out:
# {'risk': 'SAFE',
#  'decision': 'Loan Approved',
#  'reason': 'Expected profit comfortably covers loan repayment.',
#  'recommended_loan': 72000.0,
#  'advice': 'Proceed with the loan. Financial position appears healthy.'}
